# %% [markdown]
# ## Assignment 5

# %% [markdown]
# ### 1. What does an empty dictionary's code look like?
#
# **Answer:-**  An empty dictionary code ooks like:

# %%
dict_1 = {}
type(dict_1)
# Out:
# dict

# %% [markdown]
# ### 2. What is the value of a dictionary value with the key 'foo' and the value 42?
#
# **Answer:-**  In the dictionary value can be assign by using ':' operator.

# %%
dict_1 = {"foo" : 42}
dict_1["foo"]
# Out:
# 42

# %% [markdown]
# ### 3. What is the most significant distinction between a dictionary and a list?
#
# **Answer:-**
#
# 1. **List** is a ordered sequence of collection whether **dictionary** is unordered sequence of collection.
#
# 2. **List** can be accessed using index position whether **dictionary** can be accessed using key - value pair.
#
# 3. In the **list** it can be define by '[]' braces whether **dictionary** can be define by using '{}'

# %% [markdown]
# ### 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?
#
# **Answer:-**  It will gives an error as no key name 'foo' is found.

# %%
spam = {'bar': 100}
print(spam)

spam['foo']
# Out:
# {'bar': 100}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-56a19f02f3f1> in <cell line: 4>()
#       2 print(spam)
#       3
# ----> 4 spam['foo']
#
# KeyError: 'foo'

# %% [markdown]
# ### 5.If a dictionary is stored in spam,what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys() ?
#
# **Answer:-**  In 'cat' in spam operation it returns true or false it checks whether the key is present or not in the dictionary. In 'cat' in spam.keys() returns the value assigned with the 'cat'.

# %%
spam = {"cat" : "mewwoooo"}
print(spam)

"cat" in spam
# Out:
# {'cat': 'mewwoooo'}
# True

# %%
"cat" in spam.keys()
# Out:
# True

# %% [markdown]
# ### 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?
#
# **Answer:-**   Both the operation will be different as the 'cat' is a key name & is present within the dictionary. spam.values() provides all the values present within the dictionary ,So if the values match with the given value ; it will definitely return True

# %%
spam = {"cat" : "mewwoooo"}
print(spam)

"cat" in spam
# Out:
# {'cat': 'mewwoooo'}
# True

# %%
"cat" in spam.values()
# Out:
# False

# %% [markdown]
# ### 7.What is a shortcut for the following code? if 'color' not in spam: spam['color'] = 'black'
#
# **Answer:-** It automatically creates the key 'color' if it is not availble in the dictionary.

# %%
spam = {'Shruti' : 15}

spam['color'] = 'black'
print(spam)
# Out:
# {'Shruti': 15, 'color': 'black'}

# %% [markdown]
# ### 8. How do you "pretty print" dictionary values using which module and function?
#
# **Answer:-**
# 1. **pprint()** is the python built-in module that can be used to print python datatypes in a more readable way.
#
# 2. Within the pprint module; pprint() function is used to perform this operation.

# %%
import pprint


ary_1 = [{'City': 'Pune', 'Salary': 50000, 'Job': 'Python Devloper'},
     {'City': 'Mumbai', 'Salary': 80000, 'Job': 'Data Science Devloper'}]

print(ary_1)
# Out:
# [{'City': 'Pune', 'Salary': 50000, 'Job': 'Python Devloper'}, {'City': 'Mumbai', 'Salary': 80000, 'Job': 'Data Science Devloper'}]
