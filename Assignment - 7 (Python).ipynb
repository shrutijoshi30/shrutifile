# %% [markdown]
# ## Assignment 7

# %% [markdown]
# ### Q.1. Create two int type variables, apply addition, subtraction, division and multiplications and store the results in variables. Then print the data in the following format by calling the variables:
#
#
# First variable is __ & second variable is __
#
#    Addition: __ + __ = __
#
#    Subtraction: __ - __ = __
#
#
#    Multiplication: __ * __ = __
#
#    Division: __ / __ = __
#
#
# **Answer:-**

# %%
# Create two variables
n1 = 10
n2 = 20

# Perform operations and store the results
add = n1 + n2
sub = n1 - n2
mul = n1 * n2
div = n1 / n2

# Print the results
print(f"First variable is", n1, "& second variable is", n2)
print(f"Addition:", n1, "+", n2, "=", add)
print(f"Subtraction:", n1, "-", n2, "=", sub)
print(f"Multiplication:", n1, "*", n2, "=", mul)
print(f"Division:", n1, "/", n2, "=", div)
# Out:
# First variable is 10 & second variable is 20
# Addition: 10 + 20 = 30
# Subtraction: 10 - 20 = -10
# Multiplication: 10 * 20 = 200
# Division: 10 / 20 = 0.5

# %% [markdown]
# ### Q.2. What is the difference between the following operators:
#
#
#    (i) ‘/’ & ‘//’
#
#    (ii) ‘**’ & ‘^’
#
# **Answer:-**
#
# 1.  **'/' and '//':**
#
#   (a).  '/' is the division operator in Python. It performs normal division and returns the quotient as a float, even if the result is a whole number.
#
#   (b).  '//' is the floor division operator in Python. It performs division and returns the quotient as an integer, discarding the decimal part (flooring the result)

# %%
x = 10
y = 3

result = x / y         # Normal division
result_1 = x // y      # Floor division

print(result)          # Output: 3.3333333333333335
print(result_1)        # Output: 3
# Out:
# 3.3333333333333335
# 3

# %% [markdown]
# 2. **Difference between '**' and '^':**
#
#  (a).  '**' is the exponentiation operator in Python. It raises a number to the power of another number.
#
#  (b).  '^' is not a built-in operator in Python for exponentiation. Instead, it is used as the bitwise XOR operator for integer values.

# %%
x = 2
y = 4

result = x ** y        # Exponentiation

print(result)          # Output: 16
# Out:
# 16

# %% [markdown]
# ### Q.3. List the logical operators.
#
# **Answer:-**  The logical operators are used to perform logical operations on boolean values. Logical operators are as follows :
#
# 1.  **AND**: The And operator returns True value if both operands are True and False otherwise , it performs a logical AND operation.
#
# 2.  **OR**: The OR operator returns True if at least one of the operands is True or False if both operands are False ,it performs a logical 'OR' operation.
#
# 3.  **NOT**: The NOT operator is a unary operator that returns the opposite of the operand's logical value. If the operand is True, it returns False, and if the operand is False, it returns True. It performs a logical NOT operation.
#
# Following example demonstrate these logical operations

# %%
a = 5
b = 20
c = 10

# AND Operation
print(a < b and b < c)      # Result should be false

# OR Operation
print(a < b or b < c)       # Result should be true

# NOT Operation
print(not a < b)            # Result should be false
# Out:
# False
# True
# False

# %% [markdown]
# ### Q.4. Explain right shift operator and left shift operator with examples.
#
# **Answer:-**  The right shift (>>) and left shift (<<) operators are used to perform bitwise shifting operations on integer values. These operators shift the binary representation of a number to the right or left by a specified number of positions.
#
#  1. **Right Shift Operator (>>)**:
# The right shift operator (>>) shifts the bits of a number to the right by a specified number of positions. It effectively divides the number by 2 raised to the power of the shift amount. The rightmost bits are discarded, and zeros are filled in from the left.
#
#
# Following example demonstrate right shift operator.

# %%
x = 10

y = x >> 2     # Right shift by 2 positions

print(y)       # Output should be 2
# Out:
# 2

# %% [markdown]
#  2. **Left Shift Operator (<<)**:
#   The left shift operator (<<) shifts the bits of a number to the left by a specified number of positions. It effectively multiplies the number by 2 raised to the power of the shift amount. Zeros are filled in from the right, and the leftmost bits are discarded if they exceed the length of the integer's representation.
#
#   Following example demonstrate left shift operator.

# %%
a = 5

b = a << 2        # Left shift by 2 positions

print(b)     # Output should be 20
# Out:
# 20

# %% [markdown]
# ### Q.5. Create a list containing int type data of length 15. Then write a code to check if 10 is present in the list or not.
#
# **Answer:-**

# %%
list_1 = [5 , 10 , 15 , 20 , 25 , 30 , 35 , 40 , 45 , 50]

if 10 in list_1 :
    print(f"Yes ! 10 is present in the list")

else:
    print(f"Oops ! 10 is not present in the list")
# Out:
# Yes ! 10 is present in the list
