# %% [markdown]
# ## Assignment  10

# %% [markdown]
# ### Q1. What is the role of try and exception block?
#
# **Answer:-**
# 1.  The **try-except** block is used to handle exceptions or errors that may occur during the execution of a program.
#
#
# 2.  It allows you to write code that can anticipate and handle potential errors gracefully, preventing the program from crashing and allowing you to provide alternative actions or error handling mechanisms.

# %% [markdown]
# ### Q2. What is the syntax for a basic try-except block?
#
# **Answer:-**  The syntax for a basic try-except block in as follows :
#
# **try:**
#
#      Code that might create error
#      .
#
#      .
#
#      .
#
#
# **except**  ExceptionType:
#
#      Code to handle the exception
#      .
#
#      .
#
#      .

# %% [markdown]
# ### Q3. What happens if an exception occurs inside a try block and there is no matching except block?
#
# **Answer:-**
# 1.  If an exception occurs inside a try block and there is no matching except block to handle that specific exception type, the exception will propagate up the call stack.
#
# 2.  This means that the program will terminate, and the default exception handling mechanism of the programming language will come into play. Typically, this results in an error message being displayed, and the program execution is halted.
#
# 3.  When an exception is not caught and handled by an except block, it is considered an unhandled exception. The default behavior of most programming languages is to print an error message, including the type of the exception, a description of the error, and the traceback information.
#
# 4.  The traceback shows the sequence of function calls that led to the point where the exception occurred, allowing developers to trace the error back to its origin.
#
# 5.  Unhandled exceptions can cause the program to crash abruptly and may lead to unexpected behavior. They can also make it challenging to identify and fix issues in the code.
#
# 6.   It is generally recommended to handle exceptions appropriately by providing matching except blocks to catch and handle specific exception types.
#
# 7.  This allows for controlled error handling and the ability to provide customized error messages or recovery mechanisms based on the specific exception type.

# %% [markdown]
# Q5. Can you have nested try-except blocks in Python? If yes, then give an example.
#
# **Answer:-**  Yes, nested try-except blocks are allowed in Python. This means you can have a try block within another
# try block, and each try block can have its corresponding except block.
# following example demonstrate nested try-except block in python :

# %%
try:
    var_1 = 30 / 0

except ZeroDivisionError:
    print("Error: Division by zero error !")

    try:
        var_2 = int("Shruti")

    except ValueError:
        print("Error: Invalid conversion of variable")
# Out:
# Error: Division by zero error !
# Error: Invalid conversion of variable

# %% [markdown]
# ### Q6. Can we use multiple exception blocks, if yes then give an example.
#
# **Answer:-**  **Yes,** it is possible to use multiple except blocks to handle different types of exceptions:
#
# try:
#
#      Code in that error may occurs
#
#      .
#
#      .
#
#      .
#
# except ValueError:
#
#      Code to handle ValueError
#
#      .
#
#      .
#
#      .
#
# except FileNotFoundError:
#
#      Code to handle FileNotFoundError
#
#      .
#
#      .
#
#      .
#
# except:
#
#      Code to handle any other exception
#
#      .
#
#      .
#
#      .

# %% [markdown]
# ### Q7. Write the reason due to which following errors are raised:
#
# a. EOFError
#
# b. FloatingPointError
#
# c. IndexError
#
# d. MemoryError
#
# e. OverflowError
#
# f. TabError
#
# g. ValueError
#
#
# **Answer:-**
#
# **1.   EOFError:** This error occurs when the input() function or the raw_input() function reaches the end of the file or input stream unexpectedly. It typically happens when you try to read input but encounter an unexpected end of the input source.
#
# **2.   FloatingPointError:** This error occurs when a floating-point operation fails to produce a valid result. It typically occurs in situations like dividing a number by zero or performing calculations that lead to an overflow or underflow in the floating-point representation.
#
# **3.  IndexError:** This error occurs when you try to access an index of a sequence (e.g., list, tuple, or string) that is outside the valid range of indices. It happens when you try to access an element at an index that doesn't exist in the sequence.
#
# **4.   MemoryError:** This error occurs when the program's request for a specific amount of memory from the operating system fails. It indicates that the program has exhausted the available memory and cannot allocate any more.
#
# **5.   OverflowError:** This error occurs when a mathematical operation exceeds the maximum limit of a numeric type. For example, it can happen when trying to calculate an integer that is larger than the maximum value representable by the integer type.
#
# **6.   TabError:** This error occurs when there is an improper use of tabs and spaces for indentation in Python code. It usually happens when mixing tabs and spaces inconsistently or using an incorrect number of indentation spaces in an indented block.
#
# **7.   ValueError:** This error occurs when a function receives an argument of the correct type but with an invalid value. It can happen, for example, when trying to convert a string to a numeric type, but the string does not represent a valid number.

# %% [markdown]
# ### Q8. Write code for the following given scenario and add try-exception block to it.
# a. Program to divide two numbers
#
# b. Program to convert a string to an integer
#
# c. Program to access an element in a list
#
# d. Program to handle a specific exception
#
# e. Program to handle any exception
#
# **Answer:-**

# %%
#  Program to divide two numbers:

try:
    a = int(input("Enter the first number: "))
    b = int(input("Enter the second number: "))
    c = a / b
    print(f"Result is :", c)

except ZeroDivisionError:
    print("Error: Division by zero !")

except ValueError:
    print("Error: Invalid input !, please enter numbers only")
# Out:
# Enter the first number: 20
# Enter the second number: 0
# Error: Division by zero !

# %%
#  Program to convert a string to an integer:

try:
    str_1 = input("Enter a number: ")
    a = int(str_1)
    print("Number is :", a)

except ValueError:
    print("Error: Invalid input !, please enter a valid integer")
# Out:
# Enter a number: 5
# Number is : 5

# %%
#  Program to access an element in a list:

try:
    list_1 = [10, 20, 30, 40, 50]
    index = int(input("Enter an index: "))
    a = list_1[index]
    print("Element is:", a)

except IndexError:
    print("Error: Index out of range !")

except ValueError:
    print("Error: Invalid input !, please enter a valid index")
# Out:
# Enter an index: 2
# Element is: 30

# %%
# Program to handle a specific exception:

try:
    a = int(input("Enter a number: "))
    b = 10 / a
    print("Result is:", b)

except ZeroDivisionError:
    print("Error: Division by zero !")
# Out:
# Enter a number: 0
# Error: Division by zero !

# %%
# Program to handle any exception:

try:
    a = int(input("Enter the first number: "))
    b = int(input("Enter the second number: "))
    c = a / b
    print("Result is:", c)

except Exception as ex:
    print("An error occurred !:", str(ex))
# Out:
# Enter the first number: 12
# Enter the second number: 6
# Result is: 2.0
